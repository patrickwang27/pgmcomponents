# %%
import matplotlib.pyplot as plt, mpld3
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
# %matplotlib widget
plt.style.use('seaborn-paper')
import scipy.interpolate as ip
from mpld3 import plugins

# %%
fig, ax = plt.subplots(figsize=(6,6))
x, y = np.loadtxt('fwhm2_50bins_10eVstepSize.csv', delimiter=',', unpack=True)
ax.scatter(x,y, s= 6, marker='x')
ax.set_xlabel('Energy / eV')
ax.set_ylabel('Optimal Energy Range / eV')
ax.set_title('Converged Optimal Energy Range for B07c 30% Tolerance (50000 Rays)')
#axins = zoomed_inset_axes(ax, 4, loc=1)
#axins.scatter(x,y, s=6, marker='x')
#axins.set_xlim(0,400)
#axins.set_ylim(0, 0.3)
#axins.set_yticks(np.arange(0,0.31,0.01),minor=True)
#mark_inset(ax, axins, loc1=2, loc2=3, fc="none", ec="0.5")
#fig.savefig("convergeslit.png", dpi = 300)
# Out:
# Text(0.5, 1.0, 'Converged Optimal Energy Range for B07c 30% Tolerance (50000 Rays)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
E, effc  = np.loadtxt('B07_N400C1p4O1.dat', unpack=True)

# %%
inted = ip.CubicSpline(E, effc)

# %%
inted(200)
# Out:
# array(0.13921001)

# %%
plt.clf()
x = np.linspace(100,9000,10000)
plt.plot(x, inted(x), c= 'r')
plt.scatter(E,effc, s = 8, marker='^')
plt.xlim(500,3000)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
E, flux = np.loadtxt('B07flux.dat',skiprows=1, unpack=True)

# %%
plt.clf()
plt.scatter(E, flux, alpha=0.5)
flux_int = ip.CubicSpline(E, flux)
plt.plot(E, flux_int(E), c= 'black')
#plt.semilogy()
#plt.semilogx()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
2.53/1368
# Out:
# 0.0018494152046783625

# %%
spectra = np.loadtxt('resultscff14o1upto3000.csv', skiprows=2, delimiter=',', usecols=(0,1,2,3,4))

# %%
fig, ax = plt.subplots()
ax.scatter(spectra[:,0], spectra[:,3], s=6, marker='x')
ax.set_title(r"$c_{ff} = 1.4$, 400 l/mm, 1st order")
ax.grid(which='both')
plugins.connect(fig, plugins.MousePosition(fontsize=14))
#fig.show()
#mpld3.save_html(fig, 'cff14firstorder.html')
#ax.semilogy()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import csv
import json

# %%
with open("resultscff14o1upto3000.csv", 'r') as f:
    reader = csv.reader(f)
    data = list(reader)

# %%
intensities = [[float(row[0]), eval(row[-1])] for row in data[2:]]
oe4int = [intensities[x]]

# %%
fig, ax = plt.subplots()
ax.set_title(r'$c_{ff} = 1.4$, 400 l/mm, 1st order, Intensities after grating')
ax.set_ylabel('Intensity')
ax.set_xlabel('Energy / ev')
for i in arange(1, 10, 1)
# Out:
# /tmp/ipykernel_5264/3429074188.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# Text(0.5, 0, 'Energy / ev')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
E = [row[0] for row in intensities]
oe1_int = [row[1]['OE1']/50000 for row in intensities]
oe2_int = [row[1]['OE2']/row[1]['OE1'] for row in intensities]
oe3_int = [row[1]['OE3']/row[1]['OE2'] for row in intensities]
oe4_int = [row[1]['OE4']/row[1]['OE3'] for row in intensities]
oe5_int = [row[1]['OE5']/row[1]['OE4'] for row in intensities]
oe6_int = [row[1]['OE6']/row[1]['OE5'] for row in intensities]
oe7_int = [row[1]['OE7']/row[1]['OE6'] for row in intensities]
oe8_int = [row[1]['OE8']/row[1]['OE7'] for row in intensities]
oe9_int = [row[1]['OE9']/row[1]['OE8'] for row in intensities]

#    'OE7': 4660.513051679238,
#    'OE8': 3766.1725973537245,
#    'OE9': 2963.5715579857647}],
#  [1101.0,
#   {'OE1': 39031.43496659457,
#    'OE2': 39031.43496659457,
#    'OE3': 24292.906080013767,
#    'OE4': 22760.529936834137,
#    'OE5': 22760.529936834137,
#    'OE6': 18235.09178952482,
#    'OE7': 4543.868169017696,
#    'OE8': 3681.5240357117855,
#    'OE9': 2903.848328658726}],
#  [1151.0,
#   {'OE1': 39124.14909786339,
#    'OE2': 39124.14909786339,
#    'OE3': 24513.531336004562,
#    'OE4': 22521.195373532297,
#    'OE5': 22521.195373532297,
#    'OE6': 18062.466373321524,
#    'OE7': 4469.320778544153,
#    'OE8': 3629.529840127593,
#    'OE9': 2866.590132062253}],
#  [1201.0,
#   {'OE1': 39193.29394812967,
#    'OE2': 39193.29394812967,
#    'OE3': 24716.798637851007,
#    'OE4': 22319.24581713321,
#    'OE5': 22319.24581713321,
#    'OE6': 17925.844954157754,
#    'OE7': 4772.815323399001,
#    'OE8': 3881.4858533833367,
#    'OE9': 3074.1534374739645}],
#  [1251.0,
#   {'OE1': 39247.4560910632,
#    'OE2': 39247.4560910632,
#    'OE3': 24828.844484395097,
#    'OE4': 22026.27611993286,
#    'OE5': 22026.27611993286,
#    'OE6': 17724.291701784918,
#    'OE7': 4644.513642162388,
#    'OE8': 3782.5489827786114,
#    'OE9': 3001.0475251386797}],
#  [1301.0,
#   {'OE1': 39294.247458143334,
#    'OE2': 39294.247458143334,
#    'OE3': 24875.982902220603,
#    'OE4': 21690.34321273145,
#    'OE5': 21690.34321273145,
#    'OE6': 17487.218580574434,
#    'OE7': 4719.353638378926,
#    'OE8': 3848.973855986193,
#    'OE9': 3052.5815063104897}],
#  [1351.0,
#   {'OE1': 39276.89911012605,
#    'OE2': 39276.89911012605,
#    'OE3': 24875.690443627038,
#    'OE4': 21350.051988259303,
#    'OE5': 21350.051988259303,
#    'OE6': 17223.299019899765,
#    'OE7': 4326.465873412156,
#    'OE8': 3531.1166432221007,
#    'OE9': 2807.1391363991092}],
#  [1401.0,
#   {'OE1': 39284.3720975835,
#    'OE2': 39284.3720975835,
#    'OE3': 24884.017042057625,
#    'OE4': 21015.455523782308,
#    'OE5': 21015.455523782308,
#    'OE6': 16984.545194083752,
#    'OE7': 4720.42453724155,
#    'OE8': 3854.592166987707,
#    'OE9': 3065.6650295079753}],
#  [1451.0,
#   {'OE1': 39308.44198360864,
#    'OE2': 39308.44198360864,
#    'OE3': 24895.514582687436,
#    'OE4': 20745.42954616391,
#    'OE5': 20745.42954616391,
#    'OE6': 16750.205395793942,
#    'OE7': 4365.098393338777,
#    'OE8': 3566.039102409158,
#    'OE9': 2832.778237812662}],
#  [1501.0,
#   {'OE1': 39320.73098234846,
#    'OE2': 39320.73098234846,
#    'OE3': 24893.19684864183,
#    'OE4': 20451.43600233567,
#    'OE5': 20451.43600233567,
#    'OE6': 16523.538744321006,
#    'OE7': 4207.787484250183,
#    'OE8': 3438.899448855455,
#    'OE9': 2732.34110600739}],
#  [1551.0,
#   {'OE1': 39346.42144431957,
#    'OE2': 39346.42144431956,
#    'OE3': 24805.663510805087,
#    'OE4': 20122.031454784246,
#    'OE5': 20122.031454784246,
#    'OE6': 16291.321128213898,
#    'OE7': 4308.799480234733,
#    'OE8': 3524.5548416026613,
#    'OE9': 2804.5156257246335}],
#  [1601.0,
#   {'OE1': 39334.777204820624,
#    'OE2': 39334.77720482064,
#    'OE3': 24669.237165827904,
#    'OE4': 19739.73395031657,
#    'OE5': 19739.73395031657,
#    'OE6': 15975.442619024463,
#    'OE7': 4200.479663896528,
#    'OE8': 3436.864867480153,
#    'OE9': 2727.6611771594276}],
#  [1651.0,
#   {'OE1': 39313.70136273939,
#    'OE2': 39313.70136273939,
#    'OE3': 24510.317400353782,
#    'OE4': 19395.79583687478,
#    'OE5': 19395.79583687478,
#    'OE6': 15703.446201872992,
#    'OE7': 4095.1880427022074,
#    'OE8': 3351.2472422441833,
#    'OE9': 2663.2264925358895}],
#  [1701.0,
#   {'OE1': 39311.59004652145,
#    'OE2': 39311.59004652145,
#    'OE3': 24345.077160250316,
#    'OE4': 19055.594589098804,
#    'OE5': 19055.594589098804,
#    'OE6': 15446.457766880758,
#    'OE7': 4222.92175100796,
#    'OE8': 3455.9326327628287,
#    'OE9': 2746.6773583182726}],
#  [1751.0,
#   {'OE1': 39275.53874912916,
#    'OE2': 39275.53874912916,
#    'OE3': 24103.838360269456,
#    'OE4': 18664.61569355668,
#    'OE5': 18664.61569355668,
#    'OE6': 15124.527141761053,
#    'OE7': 4042.9526741457366,
#    'OE8': 3308.406039470082,
#    'OE9': 2624.5176583510206}],
#  [1801.0,
#   {'OE1': 39240.054833111455,
#    'OE2': 39240.054833111455,
#    'OE3': 23644.977485893585,
#    'OE4': 18145.5901622178,
#    'OE5': 18145.5901622178,
#    'OE6': 14705.804740929378,
#    'OE7': 3762.108606702388,
#    'OE8': 3077.9735260801544,
#    'OE9': 2439.870335408196}],
#  [1851.0,
#   {'OE1': 39145.97320559104,
#    'OE2': 39145.97320559104,
#    'OE3': 23103.760472620434,
#    'OE4': 17557.54540102626,
#    'OE5': 17557.54540102626,
#    'OE6': 14224.652282826648,
#    'OE7': 3847.858282111931,
#    'OE8': 3145.709511598278,
#    'OE9': 2491.908122682392}],
#  [1901.0,
#   {'OE1': 39103.15167664169,
#    'OE2': 39103.1516766417,
#    'OE3': 22540.820885925685,
#    'OE4': 16975.722801530883,
#    'OE5': 16975.722801530883,
#    'OE6': 13740.102757528442,
#    'OE7': 3863.4892949593414,
#    'OE8': 3155.464423193167,
#    'OE9': 2491.9125639811173}],
#  [1951.0,
#   {'OE1': 39048.779162130246,
#    'OE2': 39048.779162130246,
#    'OE3': 21560.501697619216,
#    'OE4': 16091.74040816326,
#    'OE5': 16091.74040816326,
#    'OE6': 13040.351539889452,
#    'OE7': 3386.6630347715386,
#    'OE8': 2762.938612669039,
#    'OE9': 2181.19492936975}],
#  [2001.0,
#   {'OE1': 38937.57970545673,
#    'OE2': 38937.57970545673,
#    'OE3': 20186.40930145337,
#    'OE4': 14927.95195206108,
#    'OE5': 14927.95195206108,
#    'OE6': 12089.621571271096,
#    'OE7': 3456.9702704494384,
#    'OE8': 2816.7048200123627,
#    'OE9': 2216.708543185814}],
#  [2051.0,
#   {'OE1': 38824.33476346834,
#    'OE2': 38824.33476346834,
#    'OE3': 17695.521440518256,
#    'OE4': 12949.93919184433,
#    'OE5': 12949.93919184433,
#    'OE6': 10477.89556205455,
#    'OE7': 2891.8497195329182,
#    'OE8': 2353.754992803929,
#    'OE9': 1846.8256160133894}],
#  [2101.0,
#   {'OE1': 38734.80055566758,
#    'OE2': 38734.800555667585,
#    'OE3': 11676.17644242454,
#    'OE4': 8483.500615059978,
#    'OE5': 8483.500615059978,
#    'OE6': 6857.5938963685185,
#    'OE7': 1942.2548753137416,
#    'OE8': 1578.8583314962516,
#    'OE9': 1234.915914336638}],
#  [2151.0,
#   {'OE1': 38593.752376156204,
#    'OE2': 38593.752376156204,
#    'OE3': 7538.6499555427245,
#    'OE4': 5447.855389662063,
#    'OE5': 5447.855389662063,
#    'OE6': 4403.915706617233,
#    'OE7': 1202.5622919168577,
#    'OE8': 975.5209280770708,
#    'OE9': 760.4807198186995}],
#  [2201.0,
#   {'OE1': 38441.84416059822,
#    'OE2': 38441.84416059822,
#    'OE3': 7471.087522366873,
#    'OE4': 5358.158977827138,
#    'OE5': 5358.158977827138,
#    'OE6': 4324.883900584234,
#    'OE7': 1135.3959610513402,
#    'OE8': 918.8774284436877,
#    'OE9': 713.9216055613402}],
#  [2251.0,
#   {'OE1': 38291.462448375394,
#    'OE2': 38291.462448375394,
#    'OE3': 8461.417929991843,
#    'OE4': 6026.682309571166,
#    'OE5': 6026.682309571166,
#    'OE6': 4855.386424914535,
#    'OE7': 1301.8382532997882,
#    'OE8': 1050.8191207434063,
#    'OE9': 810.7982901128748}],
#  [2301.0,
#   {'OE1': 38069.504672713825,
#    'OE2': 38069.504672713825,
#    'OE3': 9389.158511235424,
#    'OE4': 6636.340765459247,
#    'OE5': 6636.340765459247,
#    'OE6': 5339.661453233766,
#    'OE7': 1371.1321731273383,
#    'OE8': 1103.5178712768252,
#    'OE9': 847.4265770970417}],
#  [2351.0,
#   {'OE1': 37855.86950912563,
#    'OE2': 37855.86950912563,
#    'OE3': 9888.733701027368,
#    'OE4': 6936.992827849346,
#    'OE5': 6936.992827849346,
#    'OE6': 5567.5879615126405,
#    'OE7': 1410.5095927644606,
#    'OE8': 1131.5123471225443,
#    'OE9': 864.5358402709094}],
#  [2401.0,
#   {'OE1': 37588.30885798041,
#    'OE2': 37588.30885798041,
#    'OE3': 10307.483490404533,
#    'OE4': 7205.585423309024,
#    'OE5': 7205.585423309024,
#    'OE6': 5772.636000959987,
#    'OE7': 1725.7848435924557,
#    'OE8': 1379.0928072258016,
#    'OE9': 1045.753253737994}],
#  [2451.0,
#   {'OE1': 37238.22525710713,
#    'OE2': 37238.22525710713,
#    'OE3': 10613.662793591817,
#    'OE4': 7377.778969435805,
#    'OE5': 7377.778969435805,
#    'OE6': 5887.808344429387,
#    'OE7': 1631.4081885899814,
#    'OE8': 1296.75645242433,
#    'OE9': 974.7037299141986}],
#  [2501.0,
#   {'OE1': 36796.05798604877,
#    'OE2': 36796.05798604877,
#    'OE3': 10846.251291194138,
#    'OE4': 7471.980151303955,
#    'OE5': 7471.980151303955,
#    'OE6': 5943.350903038521,
#    'OE7': 1645.3970828442746,
#    'OE8': 1300.1487761826281,
#    'OE9': 966.8100753534034}],
#  [2551.0,
#   {'OE1': 36328.35299958938,
#    'OE2': 36328.35299958938,
#    'OE3': 10795.628941819701,
#    'OE4': 7411.5956465827385,
#    'OE5': 7411.5956465827385,
#    'OE6': 5878.647752563971,
#    'OE7': 1609.0950475502455,
#    'OE8': 1263.0741292796974,
#    'OE9': 926.4743393136733}],
#  [2601.0,
#   {'OE1': 35824.37920610637,
#    'OE2': 35824.37920610637,
#    'OE3': 10346.67012864345,
#    'OE4': 7036.424638128201,
#    'OE5': 7036.424638128201,
#    'OE6': 5552.512332695929,
#    'OE7': 1464.8948817850073,
#    'OE8': 1141.367713403273,
#    'OE9': 823.821456450124}],
#  [2651.0,
#   {'OE1': 35119.17457972559,
#    'OE2': 35119.17457972559,
#    'OE3': 9386.83309862314,
#    'OE4': 6370.26595119286,
#    'OE5': 6370.26595119286,
#    'OE6': 5005.887744063425,
#    'OE7': 1311.017517763603,
#    'OE8': 1010.9959253524548,
#    'OE9': 713.9753415602322}],
#  [2701.0,
#   {'OE1': 34159.03580390943,
#    'OE2': 34159.03580390943,
#    'OE3': 9774.20582808429,
#    'OE4': 6599.257967470425,
#    'OE5': 6599.257967470425,
#    'OE6': 5141.66155199086,
#    'OE7': 1373.9611167160265,
#    'OE8': 1046.344081308706,
#    'OE9': 719.4140771526622}],
#  [2751.0,
#   {'OE1': 33040.14857130921,
#    'OE2': 33040.14857130921,
#    'OE3': 9901.532666364052,
#    'OE4': 6662.805955788672,
#    'OE5': 6662.805955788672,
#    'OE6': 5149.445084710743,
#    'OE7': 1344.0575195517272,
#    'OE8': 1008.7924469117318,
#    'OE9': 668.5042533153792}],
#  [2801.0,
#   {'OE1': 31259.69359649822,
#    'OE2': 31259.693596498226,
#    'OE3': 9650.706151773407,
#    'OE4': 6442.126560011191,
#    'OE5': 6442.126560011191,
#    'OE6': 4914.2483152763025,
#    'OE7': 1384.6667530990223,
#    'OE8': 1015.3587570291032,
#    'OE9': 634.002069644174}],
#  [2851.0,
#   {'OE1': 28716.130811525723,
#    'OE2': 28716.130811525723,
#    'OE3': 9051.686298931361,
#    'OE4': 6021.7652834930905,
#    'OE5': 6021.7652834930905,
#    'OE6': 4525.023820267698,
#    'OE7': 1160.55627218929,
#    'OE8': 825.9639518837728,
#    'OE9': 469.7621431704372}],
#  [2901.0,
#   {'OE1': 24086.59056967207,
#    'OE2': 24086.59056967207,
#    'OE3': 7692.022835466017,
#    'OE4': 5089.548750050813,
#    'OE5': 5089.548750050813,
#    'OE6': 3726.286891237606,
#    'OE7': 975.6348577793054,
#    'OE8': 658.1808240506921,
#    'OE9': 316.9429684279791}],
#  [2951.0,
#   {'OE1': 15678.771214301149,
#    'OE2': 15678.771214301149,
#    'OE3': 5060.838808412885,
#    'OE4': 3331.473185908425,
#    'OE5': 3331.473185908425,
#    'OE6': 2302.362594115841,
#    'OE7': 666.4061678451463,
#    'OE8': 396.2521354110632,
#    'OE9': 133.5334481895087}],
#  [3001.0,
#   {'OE1': 7976.890793171286,
#    'OE2': 7976.890793171286,
#    'OE3': 2560.807704876218,
#    'OE4': 1680.0609951603608,
#    'OE5': 1680.0609951603608,
#    'OE6': 1009.5926738688906,
#    'OE7': 270.2716996202143,
#    'OE8': 105.17745535188689,
#    'OE9': 18.298663651982398}]]
