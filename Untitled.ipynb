# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib widget

# %%
from components import *
# Out:
# No arguments given, plane at origin with normal (0, 0, 1) initialised! Tread carefully!

# %%
mirror = Plane_Mirror.mirror_from_file('config_pgm.ini')
grating = Grating.grating_from_file('config_pgm.ini')
# Out:
# voffset
# 20
# hoffset
# 0
# axis_voffset
# 0
# axis_hoffset
# 0
# theta
# 30
# line_density
# 1100
# energy
# 80
# cff
# 2.25
# order
# 1

# %%
print(mirror)
print(grating)
# Out:
# Plane_Mirror(voffset=20.0,
#         hoffset=0.0,
#         axis_voffset=0.0,
#         axis_hoffset=0.0,
#         length=150.0,
#         width=40.0,
#         height=50.0,
#         plane=Plane(point=Point3D(x=-35.0, y=-14.142135623730951, z=14.14213562373095), normal=[ 0.         -0.70710678  0.70710678]))
# Grating(line_density=1100.0,
#  energy=80.0,
#  cff=2.25,
#  order=1.0,
#  dimensions=[1. 1. 3.])

# %%
pgm = PGM(grating=grating, mirror=mirror)

# %%
print(pgm)
# Out:
# PGM(grating=Grating(line_density=1100.0,
#  energy=80.0,
#  cff=2.25,
#  order=1.0,
#  dimensions=[1. 1. 3.]), mirror=Plane_Mirror(voffset=20.0,
#         hoffset=0.0,
#         axis_voffset=0.0,
#         axis_hoffset=0.0,
#         length=150.0,
#         width=40.0,
#         height=50.0,
#         plane=Plane(point=Point3D(x=-35.0, y=-14.142135623730951, z=14.14213562373095), normal=[ 0.         -0.70710678  0.70710678])))

# %%
pgm.grating.corners[:,1:3]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pgm.grating.corners[:,1:3]
#
# File ~/Diamond/pgm-components/components.py:204, in Grating.corners(self)
#     202 @property
#     203 def corners(self):
# --> 204     return self._corners
#
# AttributeError: 'Grating' object has no attribute '_corners'

# %%
fig,ax = plt.subplots()
ax.scatter(Out[16][:,0], Out[16][:,1])
ax.set_xlim((-370,70))
ax.set_ylim((-370,70))
# Out:
# (-370.0, 70.0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
